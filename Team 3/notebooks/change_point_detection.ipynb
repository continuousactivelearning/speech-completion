# %%
import pandas as pd
import numpy as np

# Load chunked transcripts
df = pd.read_csv('../data/processed/chunked_transcripts.csv')

# Load embeddings and assign back
embeddings = np.load('../data/processed/chunk_embeddings.npy')
df['embedding'] = list(embeddings)

# %%
import ruptures as rpt
from tqdm import tqdm

change_points_dict = {}

# group by video (speech) and run change point detection
for video_title, group in tqdm(df.groupby("VideoTitle")):
    emb = np.vstack(group["embedding"].values)
    model = rpt.Pelt(model="rbf").fit(emb)
    cp = model.predict(pen=0.6)  # can be tuned
    change_points_dict[video_title] = cp
# Out:
# 100%|███████████████████████████████████████| 101/101 [00:00<00:00, 3156.55it/s]

# %%
def assign_section_labels(df_group, change_points):
    labels = []
    last_cp = 0
    for idx, cp in enumerate(change_points):
        labels += [idx] * (cp - last_cp)
        last_cp = cp
    return labels

section_labels = []

for video_title, group in df.groupby("VideoTitle"):
    cps = change_points_dict[video_title]
    labels = assign_section_labels(group, cps)
    section_labels += labels

df["section_label"] = section_labels

# %%
df.to_csv('../data/processed/chunked_with_changepoints.csv', index=False)

# %%
df.columns.tolist()
# Out:
# ['VideoTitle', 'Chunk_ID', 'Chunk', 'embedding', 'section_label']

# %%
import json
print(json.dumps(change_points_dict, indent=2))
# Out:
# {
#   "3 Forms of Listening": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     40,
#     45,
#     51
#   ],
#   "5 Rules for Success": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     33
#   ],
#   "7 Steps to Success": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     32
#   ],
#   "75th UN General Assembly Speech": [
#     5,
#     10,
#     20,
#     25,
#     30,
#     35,
#     43
#   ],
#   "9 Life Lessons": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     45,
#     51
#   ],
#   "Abuse of Power": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     45,
#     50,
#     55,
#     60,
#     65,
#     68
#   ],
#   "America Loves India": [
#     5,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     42
#   ],
#   "Angelina_Jolie": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     45,
#     50,
#     53
#   ],
#   "Anne_Hathaway": [
#     5,
#     10,
#     15,
#     20,
#     23
#   ],
#   "Arnold_Schwarzenegger": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     35,
#     40,
#     45,
#     50,
#     55,
#     60,
#     65,
#     69
#   ],
#   "Be Brave, Not Perfect ": [
#     10,
#     15,
#     20,
#     35,
#     40,
#     50,
#     55,
#     61
#   ],
#   "Be Fearless": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     35,
#     40,
#     42
#   ],
#   "Be Funny, Be You": [
#     5,
#     10,
#     15,
#     20,
#     22
#   ],
#   "Be Nice!": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     45,
#     50,
#     55,
#     60,
#     65,
#     75,
#     84
#   ],
#   "Be Present!": [
#     5,
#     10,
#     15,
#     25,
#     30,
#     35,
#     40,
#     45,
#     50,
#     55,
#     61
#   ],
#   "Be Thankful": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     45,
#     50,
#     60,
#     65,
#     70,
#     72
#   ],
#   "Be True To Yourself": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35
#   ],
#   "Be a Winner": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     45,
#     51
#   ],
#   "Boris_Johnson": [
#     5,
#     10,
#     15
#   ],
#   "Bring a Smile": [
#     10,
#     15,
#     21
#   ],
#   "Britain owes reparations to India": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     29
#   ],
#   "Change the World": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     45,
#     50,
#     55,
#     60,
#     62
#   ],
#   "Commencement speech at Harvard University": [
#     5,
#     10,
#     15,
#     20,
#     26
#   ],
#   "Demi_Lovato": [
#     5,
#     10,
#     15,
#     24
#   ],
#   "Denzel_Washington": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     27
#   ],
#   "Discipline and Success": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     45,
#     50,
#     55,
#     65,
#     71
#   ],
#   "Don't Hesitate": [
#     5,
#     10,
#     15,
#     20,
#     22
#   ],
#   "Don\u2019t Doubt Yourself": [
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     45,
#     55,
#     60,
#     65,
#     70,
#     72
#   ],
#   "Education Changes the World": [
#     5,
#     10,
#     15
#   ],
#   "Education First": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     37
#   ],
#   "Elon_Musk": [
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     49
#   ],
#   "Emotional Eulogy for His Father": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     36
#   ],
#   "Emotional Speech": [
#     5,
#     15,
#     20,
#     30,
#     35,
#     40,
#     45,
#     50,
#     57
#   ],
#   "Explore your Opportunities": [
#     10,
#     15,
#     20,
#     25,
#     35,
#     40,
#     45,
#     50
#   ],
#   "First Speech as King ": [
#     5,
#     10,
#     16
#   ],
#   "Glenn_Close": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     42
#   ],
#   "Global Health Care": [
#     5,
#     10,
#     20,
#     25,
#     30,
#     35,
#     40,
#     45
#   ],
#   "HeForShe Impact": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     29
#   ],
#   "How to Face Fear": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     45,
#     50,
#     55
#   ],
#   "How to Stop A Bully": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     45,
#     50,
#     55,
#     65,
#     70,
#     75,
#     80,
#     85,
#     89
#   ],
#   "Importance of Education": [
#     5,
#     10,
#     15,
#     24
#   ],
#   "India in 2030": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     33
#   ],
#   "India vs Pakistan at the UN": [
#     5,
#     10,
#     16
#   ],
#   "India's Democratic Walk": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     45,
#     50,
#     55,
#     65
#   ],
#   "India's Five Pledges": [
#     5,
#     10,
#     20,
#     25,
#     30,
#     36
#   ],
#   "India's Right Path": [
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     45,
#     55,
#     62
#   ],
#   "India-Australia Partnership": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     33
#   ],
#   "JD_Vance": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40
#   ],
#   "Jeff_Bezos": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30
#   ],
#   "Jennifer_Lawrence": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     39
#   ],
#   "Joe_Biden": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     41
#   ],
#   "Justin_Trudeau": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     33
#   ],
#   "Kate_Winslet": [
#     5,
#     15,
#     25,
#     30,
#     35,
#     40,
#     45,
#     50,
#     55,
#     60,
#     65,
#     71
#   ],
#   "Kristen_Bell": [
#     5,
#     10,
#     15,
#     25,
#     30,
#     35,
#     40,
#     50
#   ],
#   "Mega Mass Party 2023": [
#     5,
#     10,
#     15,
#     25,
#     30,
#     35,
#     38
#   ],
#   "Michelle_Obama": [
#     5,
#     10,
#     20,
#     25,
#     28
#   ],
#   "Mother_Teresa": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     29
#   ],
#   "Mr_Bean": [
#     5,
#     10,
#     18
#   ],
#   "Muniba_Mazari": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     45,
#     50,
#     60,
#     65,
#     70,
#     75,
#     80,
#     85,
#     87
#   ],
#   "Nelson_Mandela": [
#     5,
#     10,
#     14
#   ],
#   "Next!": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35
#   ],
#   "Nita_Ambani": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     35,
#     40,
#     43
#   ],
#   "Paid Family Leave": [
#     5,
#     10,
#     20,
#     25,
#     30
#   ],
#   "People Can Change": [
#     5,
#     10,
#     15,
#     20,
#     25
#   ],
#   "Power of Dreams": [
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     43
#   ],
#   "Protecting Humanity": [
#     5,
#     10,
#     15,
#     19
#   ],
#   "Protecting Our Planet": [
#     5,
#     10,
#     15,
#     20
#   ],
#   "Purpose in Life": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     40,
#     43
#   ],
#   "Queen_Elizabeth": [
#     5,
#     10,
#     15,
#     20
#   ],
#   "RIHANNA": [
#     10,
#     19
#   ],
#   "R_Madhavan": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     45
#   ],
#   "Road Safety": [
#     10,
#     20,
#     25,
#     30,
#     35,
#     40,
#     45,
#     50,
#     60,
#     63
#   ],
#   "Sara_Ali_Khan": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40
#   ],
#   "Serve Humanity": [
#     5,
#     10,
#     15,
#     20,
#     35,
#     40,
#     45
#   ],
#   "Severn_Suzuki": [
#     5,
#     10,
#     15,
#     19
#   ],
#   "Shereen_Salama": [
#     5,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     45,
#     50,
#     55
#   ],
#   "Stand Up and Speak Up": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     28
#   ],
#   "Stanford Speech": [
#     10,
#     15,
#     25,
#     30,
#     40,
#     45,
#     49
#   ],
#   "Steven_Spielberg": [
#     5,
#     15,
#     20,
#     25,
#     30,
#     40,
#     50,
#     54
#   ],
#   "Survival Mode": [
#     5,
#     10,
#     15,
#     20,
#     23
#   ],
#   "The Benefits Of Failure": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     42
#   ],
#   "The Harvard Spring": [
#     5,
#     15,
#     17
#   ],
#   "The Power Of Words": [
#     5,
#     10,
#     15,
#     20,
#     25
#   ],
#   "The Power of Information": [
#     5,
#     10,
#     15,
#     20,
#     25
#   ],
#   "The Pursuit of Happiness": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     45,
#     51
#   ],
#   "Think Big Again": [
#     5,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40
#   ],
#   "Tim_Cook": [
#     5,
#     15,
#     20,
#     25,
#     30,
#     40,
#     45
#   ],
#   "Transforming India": [
#     5,
#     10,
#     20,
#     25,
#     30,
#     35,
#     39
#   ],
#   "Tribute to Kobe Bryant": [
#     5,
#     10,
#     15,
#     20,
#     26
#   ],
#   "Victory Speech": [
#     5,
#     15,
#     18
#   ],
#   "WSU Tech 2020": [
#     5,
#     10,
#     15,
#     20,
#     25
#   ],
#   "We Are All History": [
#     5,
#     15,
#     20,
#     25,
#     30,
#     36
#   ],
#   "We're Bound": [
#     5,
#     10,
#     15,
#     20,
#     22
#   ],
#   "We\u2019re All the Same": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     41
#   ],
#   "What Do We Stand For": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     36
#   ],
#   "What We Stand For": [
#     5,
#     20,
#     25,
#     30,
#     38
#   ],
#   "Why Not Me?": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     45,
#     50,
#     55,
#     60,
#     65,
#     69
#   ],
#   "Will You Join Us?": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     35,
#     40,
#     45,
#     51
#   ],
#   "Women\u2019s Empowerment": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     30,
#     35,
#     40,
#     46
#   ],
#   "Yes We Can": [
#     5,
#     10,
#     15,
#     20,
#     25,
#     28
#   ],
#   "You Can Do It": [
#     5,
#     10,
#     15,
#     20,
#     24
#   ]
# }

# %%
last_cp_progress = []

for video_title, group in df.groupby("VideoTitle"):
    cps = change_points_dict.get(video_title, [])
    last_cp = max(cps) if cps else len(group)
    total_chunks = len(group)
    
    for i in range(total_chunks):
        # Progress capped at 100%
        pct = (i / last_cp) * 100 if i <= last_cp else 100
        last_cp_progress.append(min(pct, 100))

df["speech_progress_percent"] = last_cp_progress

# %%
df.columns.tolist()
# Out:
# ['VideoTitle',
#  'Chunk_ID',
#  'Chunk',
#  'embedding',
#  'section_label',
#  'speech_progress_percent']

# %%
sample_title = "75th UN General Assembly Speech"
sample_df = df[df["VideoTitle"] == sample_title]

sample_df[["Chunk", "section_label", "speech_progress_percent"]].head(10)
# Out:
#                                                   Chunk  section_label  \
# 3480  Thank you, Representatives of the member state...              5
# 3481  And two years ago here, I asked your name. I u...              5
# 3482  As a boy from the small city of Ilsan in Korea...              6
# 3483  All of our plans went away and I became alone....              6
# 3484  I remember the words I spoke here two years ag...              6
# 3485  We must try to love ourselves and imagine the ...              6
# 3486  But the stars shine brightest when the night i...              6
# 3487  Let’s reimagine our world. We’re huddled toget...              0
# 3488  Let’s dream about a future when our words can ...              0
# 3489             Life goes on. Life goes on. Life goes.              0
#
#       speech_progress_percent
# 3480                82.500000
# 3481                85.000000
# 3482                87.500000
# 3483                90.000000
# 3484                92.500000
# 3485                95.000000
# 3486                97.500000
# 3487                 0.000000
# 3488                 2.222222
# 3489                 4.444444

# %%
sample_title = "How to Stop A Bully"
sample_df = df[df["VideoTitle"] == sample_title]

sample_df[["Chunk", "section_label", "speech_progress_percent"]].head(10)
# Out:
#                                                   Chunk  section_label  \
# 2823  How you guys doing? Good, good good good good....              6
# 2824  My brother and my sister were born with arms a...              7
# 2825  I’m from Australia, anybody want to one day go...              7
# 2826  So I only live about four hours from here. And...              7
# 2827  Can you imagine if I’m driving a car? They rec...              0
# 2828  Imagine if I get pulled over by the cops? Can ...              0
# 2829  Imagine if I’m in big trouble! Put your hands ...              0
# 2830  Uhhhhh… So I’m in the front passenger’s seat, ...              0
# 2831  She has no idea that I have no arms and no leg...              0
# 2832  So I get the seatbelt in my mouth, and I loose...              1
#
#       speech_progress_percent
# 2823                90.697674
# 2824                93.023256
# 2825                95.348837
# 2826                97.674419
# 2827                 0.000000
# 2828                 5.000000
# 2829                10.000000
# 2830                15.000000
# 2831                20.000000
# 2832                25.000000

# %%
def get_completion_percent(video_title, current_chunk_index):
    cps = change_points_dict.get(video_title, [])
    if not cps:
        return 0.0
    last_cp = max(cps)
    if current_chunk_index >= last_cp:
        return 100.0
    return round((current_chunk_index / last_cp) * 100, 2)

# %%
print(get_completion_percent("75th UN General Assembly Speech", 5))
# Out:
# 11.63

# %%
df.columns.tolist()
# Out:
# ['VideoTitle',
#  'Chunk_ID',
#  'Chunk',
#  'embedding',
#  'section_label',
#  'speech_progress_percent']
