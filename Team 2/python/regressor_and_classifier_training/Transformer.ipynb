# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras import layers, Input, Model
from tensorflow.keras.preprocessing.sequence import pad_sequences

# PARAMETERS
INPUT_PATH = "./progress_added.csv"
NUM_CLASSES = 20
EMBED_DIM = 384    # MiniLM embedding size
NUM_HEADS = 4
FF_DIM = 128        # Feed-forward layer hidden dim
TRANSFORMER_LAYERS = 2

# Load CSV and preprocess
df = pd.read_csv(INPUT_PATH)
df = df[df["cluster"] != -1]
df = df[df["text"].notnull() & df["text"].str.strip().astype(bool)]
print(f"Loaded {len(df)} rows (without noise)")

# Convert string embeddings to arrays
df["embedding"] = df["embedding"].apply(lambda x: np.array(eval(x), dtype=np.float32))

# Build sequences (by file)
X = []
y = []

for file_name, group in tqdm(df.groupby("file")):
    group = group.sort_values("start_sec")
    sequence = []
    for _, row in group.iterrows():
        sequence.append(row["embedding"])
        X.append(sequence.copy())
        y.append(int(row["progress_label"]))

print(f"Prepared {len(X)} sequences")

# Pad all sequences
X_padded = pad_sequences(X, dtype='float32', padding='post')

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_padded, y, test_size=0.2, random_state=42
)

print(f"Train size: {len(X_train)}, Test size: {len(X_test)}")

# Positional Encoding Layer
class PositionalEncoding(layers.Layer):
    def __init__(self, maxlen, embed_dim):
        super().__init__()
        self.pos_embedding = self.add_weight(
            shape=(1, maxlen, embed_dim),
            initializer="random_normal",
            trainable=True
        )

    def call(self, x):
        return x + self.pos_embedding[:, :tf.shape(x)[1], :]

# Transformer Encoder Block
def transformer_encoder(inputs):
    # Multi-head self-attention
    attn_output = layers.MultiHeadAttention(num_heads=NUM_HEADS, key_dim=EMBED_DIM)(inputs, inputs)
    attn_output = layers.Dropout(0.1)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(inputs + attn_output)

    # Feed-forward network
    ffn = layers.Dense(FF_DIM, activation="relu")(out1)
    ffn = layers.Dense(EMBED_DIM)(ffn)
    ffn = layers.Dropout(0.1)(ffn)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn)

# Model definition
max_seq_len = X_padded.shape[1]

inputs = Input(shape=(max_seq_len, EMBED_DIM))
x = PositionalEncoding(max_seq_len, EMBED_DIM)(inputs)

for _ in range(TRANSFORMER_LAYERS):
    x = transformer_encoder(x)

x = layers.GlobalAveragePooling1D()(x)
x = layers.Dense(64, activation='relu')(x)  # Non-linear layer
outputs = layers.Dense(NUM_CLASSES, activation='softmax')(x)  # Output probabilities

model = Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()

# Train
history = model.fit(
    X_train, np.array(y_train),
    validation_data=(X_test, np.array(y_test)),
    epochs=10,
    batch_size=32
)

# Evaluate
loss, acc = model.evaluate(X_test, np.array(y_test))
print(f"\nTest Accuracy: {acc:.4f}")

# Predict and visualize
preds = model.predict(X_test).argmax(axis=1)
print("\nClassification Report:")
print(classification_report(y_test, preds))

cm = confusion_matrix(y_test, preds)
plt.figure(figsize=(6,6))
plt.imshow(cm, cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.colorbar()
plt.show()
# Out:
# Loaded 2622 rows (without noise)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:00<00:00, 82.14it/s]
# Prepared 2622 sequences
# Train size: 2097, Test size: 525
# WARNING:tensorflow:From C:\Users\ved\Desktop\Speech-Completition-Prediction\python\.venv\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 303, 384)          │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ positional_encoding           │ (None, 303, 384)          │         116,352 │ input_layer[0][0]          │
# │ (PositionalEncoding)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention          │ (None, 303, 384)          │       2,364,288 │ positional_encoding[0][0], │
# │ (MultiHeadAttention)          │                           │                 │ positional_encoding[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 303, 384)          │               0 │ multi_head_attention[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 303, 384)          │               0 │ positional_encoding[0][0], │
# │                               │                           │                 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization           │ (None, 303, 384)          │             768 │ add[0][0]                  │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 303, 128)          │          49,280 │ layer_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 303, 384)          │          49,536 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 303, 384)          │               0 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 303, 384)          │               0 │ layer_normalization[0][0], │
# │                               │                           │                 │ dropout_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_1         │ (None, 303, 384)          │             768 │ add_1[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_1        │ (None, 303, 384)          │       2,364,288 │ layer_normalization_1[0][… │
# │ (MultiHeadAttention)          │                           │                 │ layer_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_4 (Dropout)           │ (None, 303, 384)          │               0 │ multi_head_attention_1[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_2 (Add)                   │ (None, 303, 384)          │               0 │ layer_normalization_1[0][… │
# │                               │                           │                 │ dropout_4[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_2         │ (None, 303, 384)          │             768 │ add_2[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 303, 128)          │          49,280 │ layer_normalization_2[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 303, 384)          │          49,536 │ dense_2[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_5 (Dropout)           │ (None, 303, 384)          │               0 │ dense_3[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 303, 384)          │               0 │ layer_normalization_2[0][… │
# │                               │                           │                 │ dropout_5[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_3         │ (None, 303, 384)          │             768 │ add_3[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling1d      │ (None, 384)               │               0 │ layer_normalization_3[0][… │
# │ (GlobalAveragePooling1D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_4 (Dense)               │ (None, 64)                │          24,640 │ global_average_pooling1d[… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_5 (Dense)               │ (None, 20)                │           1,300 │ dense_4[0][0]              │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 5,071,572 (19.35 MB)
#  Trainable params: 5,071,572 (19.35 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 290s 4s/step - accuracy: 0.0939 - loss: 2.8767 - val_accuracy: 0.1733 - val_loss: 2.3235
# Epoch 2/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 264s 4s/step - accuracy: 0.2245 - loss: 2.0909 - val_accuracy: 0.2457 - val_loss: 1.9474
# Epoch 3/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 280s 4s/step - accuracy: 0.3181 - loss: 1.6458 - val_accuracy: 0.3162 - val_loss: 1.5573
# Epoch 4/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 277s 4s/step - accuracy: 0.4073 - loss: 1.3758 - val_accuracy: 0.4305 - val_loss: 1.3662
# Epoch 5/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 243s 4s/step - accuracy: 0.3934 - loss: 1.4047 - val_accuracy: 0.4400 - val_loss: 1.2813
# Epoch 6/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 245s 4s/step - accuracy: 0.4155 - loss: 1.2945 - val_accuracy: 0.4952 - val_loss: 1.1545
# Epoch 7/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 246s 4s/step - accuracy: 0.5437 - loss: 1.0717 - val_accuracy: 0.5714 - val_loss: 0.9933
# Epoch 8/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 252s 4s/step - accuracy: 0.5512 - loss: 1.0106 - val_accuracy: 0.5200 - val_loss: 1.0268
# Epoch 9/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 287s 4s/step - accuracy: 0.5657 - loss: 0.9536 - val_accuracy: 0.7524 - val_loss: 0.6738
# Epoch 10/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 293s 4s/step - accuracy: 0.5897 - loss: 1.0132 - val_accuracy: 0.5524 - val_loss: 0.9465
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.5821 - loss: 0.9220
#
# Test Accuracy: 0.5524
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        21
#            1       0.45      1.00      0.62        21
#            2       0.95      0.81      0.88        26
#            3       0.96      0.79      0.86        28
#            4       0.76      0.70      0.73        27
#            5       0.72      0.75      0.73        24
#            6       0.74      1.00      0.85        25
#            7       0.70      0.73      0.71        22
#            8       0.73      0.41      0.52        27
#            9       0.64      0.55      0.59        29
#           10       0.46      0.68      0.55        19
#           11       0.48      0.42      0.44        24
#           12       0.17      0.08      0.11        24
#           13       0.51      0.76      0.61        33
#           14       0.43      0.10      0.16        31
#           15       0.39      0.97      0.56        32
#           16       0.17      0.12      0.14        24
#           17       0.35      0.27      0.30        26
#           18       0.44      0.12      0.19        34
#           19       0.53      0.82      0.65        28
#
#     accuracy                           0.55       525
#    macro avg       0.53      0.55      0.51       525
# weighted avg       0.54      0.55      0.51       525
# C:\Users\ved\Desktop\Speech-Completition-Prediction\python\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\ved\Desktop\Speech-Completition-Prediction\python\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\ved\Desktop\Speech-Completition-Prediction\python\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
