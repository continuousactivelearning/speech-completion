# %%
import pandas as pd

from keybert import KeyBERT

df = pd.read_csv("../clustering/intermediate_data/clustered_embeddings.csv")
df = df[df["text"].notnull() & df["cluster"].notnull()]

grouped = df.groupby("cluster")["text"].apply(lambda x: " ".join(x)).reset_index()
grouped.columns = ["cluster", "combined_text"]

kw_model = KeyBERT()
def keybert_keywords(text, top_n=5):
    keywords = kw_model.extract_keywords(text, top_n=top_n)
    return [k[0] for k in keywords]

for i, row in grouped.iterrows():
    print(f"\nCluster {row['cluster']}")
    print("KeyBERT:", keybert_keywords(row["combined_text"]))
# Out:
# Cluster -1
# KeyBERT: ['graphs', 'vertex', 'finiteness', 'notions', 'graph']
#
# Cluster 0
# KeyBERT: ['couples', 'party', 'couple', 'people', 'handshakes']
#
# Cluster 1
# KeyBERT: ['lecture', 'modules', 'class', 'axioms', 'shall']
#
# Cluster 2
# KeyBERT: ['matching', 'subsets', 'subset', 'matched', 'disjoint']
#
# Cluster 3
# KeyBERT: ['music', 'graphs', 'edges', 'bipartite', 'graph']
#
# Cluster 4
# KeyBERT: ['music', 'mathematics', 'integers', 'numbers', 'lecture']
#
# Cluster 5
# KeyBERT: ['river', 'bridges', 'bridge', 'island', 'islands']
#
# Cluster 6
# KeyBERT: ['tree', 'nodes', 'leaf', 'node', 'iterative']
#
# Cluster 7
# KeyBERT: ['matchings', 'matching', 'matched', 'match', 'subsets']
#
# Cluster 8
# KeyBERT: ['graph', 'vertex', 'vertices', 'handshake', 'paired']
#
# Cluster 9
# KeyBERT: ['matchings', 'maximal', 'matching', 'vertex', 'maximum']
#
# Cluster 10
# KeyBERT: ['matchings', 'matching', 'graphs', 'graph', 'matched']
#
# Cluster 11
# KeyBERT: ['jump', 'jumping', 'progression', 'arithmetic', 'falling']
#
# Cluster 12
# KeyBERT: ['prime', 'fraction', 'construct', 'constructed', 'differs']
#
# Cluster 13
# KeyBERT: ['decimal', 'fractions', 'digits', 'numbers', 'tenth']
#
# Cluster 14
# KeyBERT: ['neighbors', 'neighbor', 'vertex', 'vn', 'block']
#
# Cluster 15
# KeyBERT: ['social', 'connections', 'graphs', 'search', 'searching']
#
# Cluster 16
# KeyBERT: ['neighbors', 'dfs', 'neighbor', 'adjacency', 'nodes']
#
# Cluster 17
# KeyBERT: ['equals', 'arithmetic', 'greater', 'integers', 'qr']
#
# Cluster 18
# KeyBERT: ['vertex', 'vertices', 'ordering', 'rows', 'order']
#
# Cluster 19
# KeyBERT: ['vertex', 'queue', 'vertices', 'processing', 'process']
#
# Cluster 20
# KeyBERT: ['graph', 'vertex', 'vertices', 'neighbors', 'edges']
#
# Cluster 21
# KeyBERT: ['ancestor', 'level', 'layers', 'layer', 'apart']
#
# Cluster 22
# KeyBERT: ['equinumerous', 'line', 'interval', 'map', 'mapping']
#
# Cluster 23
# KeyBERT: ['graphs', 'graph', 'drawing', 'vertices', 'edges']
#
# Cluster 24
# KeyBERT: ['divides', 'integers', 'divide', 'minus', 'integer']
#
# Cluster 25
# KeyBERT: ['drawing', 'paths', 'draw', 'drawn', 'crossings']
#
# Cluster 26
# KeyBERT: ['divides', 'relation', 'integers', 'power', 'prove']
#
# Cluster 27
# KeyBERT: ['stranded', 'diverge', 'continue', 'let', 'come']
#
# Cluster 28
# KeyBERT: ['minus', 'positive', 'understand', 'format', 'contradiction']
#
# Cluster 29
# KeyBERT: ['bipartite', 'graphs', 'graph', 'vertices', 'edges']
#
# Cluster 30
# KeyBERT: ['bipartite', 'cycle', 'cycles', 'graph', 'vertex']
#
# Cluster 31
# KeyBERT: ['coloring', 'graph', 'vertex', 'prime', 'vertices']
#
# Cluster 32
# KeyBERT: ['numbers', 'lcm', 'number', 'thousand', 'integer']
#
# Cluster 33
# KeyBERT: ['axioms', 'continuums', 'theory', 'continuum', 'hypothesis']
#
# Cluster 34
# KeyBERT: ['congruent', 'congruence', 'modulus', 'modulo', 'divided']
#
# Cluster 35
# KeyBERT: ['timeconsuming', 'counters', 'numbers', 'multiply', 'equals']
#
# Cluster 36
# KeyBERT: ['algorithm', 'processing', 'process', 'color', 'music']
#
# Cluster 37
# KeyBERT: ['divides', 'factorial', 'composite', 'primes', 'integers']
#
# Cluster 38
# KeyBERT: ['flow', 'flows', 'graphs', 'edges', 'flowing']
#
# Cluster 39
# KeyBERT: ['coloring', 'greedy', 'chromatic', 'algorithm', 'colors']
#
# Cluster 40
# KeyBERT: ['neighbors', 'neighbor', 'seven', 'nodes', 'node']
#
# Cluster 41
# KeyBERT: ['congruence', 'congruent', 'divides', 'modulo', 'divisible']
#
# Cluster 42
# KeyBERT: ['gcd', 'theorem', 'remainder', 'integer', 'minus']
#
# Cluster 43
# KeyBERT: ['cardinality', 'cardinalities', 'cardinal', 'kappa', 'lambda']
#
# Cluster 44
# KeyBERT: ['residues', 'congruent', 'modulo', 'residue', 'integers']
#
# Cluster 45
# KeyBERT: ['squared', 'square', 'multiplied', 'equal', 'squad']
#
# Cluster 46
# KeyBERT: ['vertex', 'vortex', 'colors', 'color', 'initialization']
#
# Cluster 47
# KeyBERT: ['explored', 'vertex', 'explore', 'gray', 'colored']
#
# Cluster 48
# KeyBERT: ['neighbors', 'neighbor', 'calls', 'white', 'color']
#
# Cluster 49
# KeyBERT: ['divides', 'theorem', 'prime', 'divide', 'arithmetic']
#
# Cluster 50
# KeyBERT: ['cube', 'colors', 'neighbors', 'queue', 'recursive']
#
# Cluster 51
# KeyBERT: ['queue', 'processing', 'process', 'processed', 'node']
#
# Cluster 52
# KeyBERT: ['prime', 'distinct', 'unique', 'theorem', 'pair']
#
# Cluster 53
# KeyBERT: ['congruent', 'modulo', 'divides', 'modulus', 'divided']
#
# Cluster 54
# KeyBERT: ['congruent', 'modem', 'congruence', 'modulo', 'transitivity']
#
# Cluster 55
# KeyBERT: ['algorithms', 'algorithm', 'algorithmic', 'iterative', 'crystals']
#
# Cluster 56
# KeyBERT: ['algorithm', 'remainders', 'remainder', 'division', 'integers']
#
# Cluster 57
# KeyBERT: ['enumeration', 'enumerate', 'sets', 'counts', 'count']
#
# Cluster 58
# KeyBERT: ['primes', 'integers', 'prime', 'integer', 'arithmetic']
#
# Cluster 59
# KeyBERT: ['graph', 'vertex', 'vertices', 'edges', 'red']
#
# Cluster 60
# KeyBERT: ['relation', 'divides', 'transitivity', 'divisibility', 'reflexive']
#
# Cluster 61
# KeyBERT: ['root', 'multiplication', 'complex', 'addition', 'equal']
#
# Cluster 62
# KeyBERT: ['norm', 'multiplication', 'square', 'members', 'equal']
#
# Cluster 63
# KeyBERT: ['nonnegative', 'multiplication', 'multiplied', 'minus', 'absolute']
#
# Cluster 64
# KeyBERT: ['colors', 'coloring', 'color', 'pink', 'numbers']
#
# Cluster 65
# KeyBERT: ['factors', 'cancel', 'fraction', 'intuitively', 'reduce']
#
# Cluster 66
# KeyBERT: ['symmetric', 'minus', 'qi', 'qd', 'corresponding']
#
# Cluster 67
# KeyBERT: ['divides', 'division', 'divide', 'divisibility', 'board']
#
# Cluster 68
# KeyBERT: ['gcd', 'divides', 'contradiction', 'integers', 'integer']
#
# Cluster 69
# KeyBERT: ['gcd', 'divides', 'divisibility', 'factor', 'integer']
#
# Cluster 70
# KeyBERT: ['integers', 'minus', 'linear', 'equation', 'division']
#
# Cluster 71
# KeyBERT: ['coefficients', 'linear', 'combination', 'values', 'weights']
#
# Cluster 72
# KeyBERT: ['integers', 'divides', 'pq', 'integer', 'ax']
#
# Cluster 73
# KeyBERT: ['integers', 'integer', 'divide', 'dy', 'cy']
#
# Cluster 74
# KeyBERT: ['coloring', 'blues', 'blue', 'color', 'red']
#
# Cluster 75
# KeyBERT: ['prime', 'integers', 'numbers', 'factors', 'number']
#
# Cluster 76
# KeyBERT: ['gcd', 'curse', 'remainder', 'numbers', 'division']
#
# Cluster 77
# KeyBERT: ['precedence', 'enumeration', 'numbering', 'precedes', 'function']
#
# Cluster 78
# KeyBERT: ['coloring', 'bipartite', 'graphs', 'colors', 'vertices']
#
# Cluster 79
# KeyBERT: ['subsets', 'subset', 'relation', 'sets', 'inclusion']
#
# Cluster 80
# KeyBERT: ['lattice', 'prime', 'pairs', 'integers', 'lower']
#
# Cluster 81
# KeyBERT: ['primes', 'prime', 'exponents', 'exponent', 'integers']
#
# Cluster 82
# KeyBERT: ['primes', 'divides', 'prime', 'divide', 'distinct']
#
# Cluster 83
# KeyBERT: ['predecessor', 'successor', 'preceding', 'relation', 'immediate']
#
# Cluster 84
# KeyBERT: ['rational', 'partitions', 'complement', 'belonging', 'set']
#
# Cluster 85
# KeyBERT: ['dedekind', 'rational', 'irrational', 'sets', 'subset']
#
# Cluster 86
# KeyBERT: ['defined', 'notions', 'definition', 'paradoxes', 'paradox']
#
# Cluster 87
# KeyBERT: ['mapping', 'isomorphism', 'map', 'maps', 'mathematically']
#
# Cluster 88
# KeyBERT: ['axiom', 'axiomatization', 'axioms', 'subsets', 'set']
#
# Cluster 89
# KeyBERT: ['uncountable', 'countable', 'injective', 'rational', 'sets']
#
# Cluster 90
# KeyBERT: ['colorable', 'colors', 'graphs', 'colored', 'vertices']
#
# Cluster 91
# KeyBERT: ['antichains', 'antichain', 'anti', 'chain', 'elements']
#
# Cluster 92
# KeyBERT: ['chains', 'enumeration', 'chain', 'relation', 'elements']
#
# Cluster 93
# KeyBERT: ['sets', 'subsets', 'subset', 'singletons', 'power']
#
# Cluster 94
# KeyBERT: ['inductive', 'sets', 'numbers', 'set', 'defined']
#
# Cluster 95
# KeyBERT: ['maximal', 'induction', 'inductively', 'diagrams', 'diagram']
#
# Cluster 96
# KeyBERT: ['elements', 'minimal', 'element', 'diagrams', 'diagram']
#
# Cluster 97
# KeyBERT: ['gcd', 'factorizations', 'lcm', 'integers', 'mode']
#
# Cluster 98
# KeyBERT: ['cardinality', 'equinumerous', 'sets', 'subsets', 'pigeonhole']
#
# Cluster 99
# KeyBERT: ['coloring', 'vertex', 'vertices', 'colors', 'colored']
#
# Cluster 100
# KeyBERT: ['vertex', 'edges', 'vertices', 'colors', 'edge']
#
# Cluster 101
# KeyBERT: ['axioms', 'associativity', 'symbols', 'boolean', 'operators']
#
# Cluster 102
# KeyBERT: ['lattice', 'lattices', 'operators', 'subset', 'axiom']
#
# Cluster 103
# KeyBERT: ['functions', 'sets', 'superscript', 'defined', 'function']
#
# Cluster 104
# KeyBERT: ['axiom', 'belongs', 'paradox', 'belong', 'belonging']
#
# Cluster 105
# KeyBERT: ['theoretic', 'integers', 'theories', 'theory', 'numbers']
#
# Cluster 106
# KeyBERT: ['extensions', 'offsets', 'equal', 'sets', 'axiom']
#
# Cluster 107
# KeyBERT: ['nominee', 'nominees', 'axiom', 'inductive', 'member']
#
# Cluster 108
# KeyBERT: ['cardinality', 'cardinalities', 'countable', 'cantor', 'definition']
#
# Cluster 109
# KeyBERT: ['cardinality', 'cardinal', 'finite', 'infinite', 'sets']
#
# Cluster 110
# KeyBERT: ['coloring', 'colors', 'color', 'require', 'graph']
#
# Cluster 111
# KeyBERT: ['coprime', 'gcd', 'divides', 'divisor', 'integers']
#
# Cluster 112
# KeyBERT: ['addition', 'multiplication', 'operations', 'recursively', 'defining']
#
# Cluster 113
# KeyBERT: ['operations', 'integers', 'operation', 'rational', 'integer']
#
# Cluster 114
# KeyBERT: ['chromatic', 'graph', 'colors', 'color', 'colored']
#
# Cluster 115
# KeyBERT: ['chromatic', 'colors', 'graphs', 'graph', 'color']
#
# Cluster 116
# KeyBERT: ['graphs', 'graph', 'mathematics', 'vertex', 'mathematical']
#
# Cluster 117
# KeyBERT: ['lcm', 'multiples', 'divides', 'gcd', 'theorem']
#
# Cluster 118
# KeyBERT: ['divides', 'lcm', 'divide', 'divided', 'numbers']
#
# Cluster 119
# KeyBERT: ['orderings', 'intercedes', 'ordering', 'precedes', 'incomparable']
#
# Cluster 120
# KeyBERT: ['pairs', 'relation', 'pair', 'integers', 'numbers']
#
# Cluster 121
# KeyBERT: ['walk', 'draw', 'vertex', 'visited', 'thousand']
#
# Cluster 122
# KeyBERT: ['regions', 'faces', 'phases', 'region', 'boundary']
#
# Cluster 123
# KeyBERT: ['vertex', 'vertices', 'edges', 'graph', 'edge']
#
# Cluster 124
# KeyBERT: ['supremum', 'sets', 'upper', 'lower', 'infimum']
#
# Cluster 125
# KeyBERT: ['strings', 'string', 'alphabet', 'finite', 'characters']
#
# Cluster 126
# KeyBERT: ['strings', 'orderings', 'string', 'tuples', 'length']
#
# Cluster 127
# KeyBERT: ['induction', 'prime', 'minus', 'hypothesis', 'equal']
#
# Cluster 128
# KeyBERT: ['cycle', 'cycles', 'hamiltonian', 'cycling', 'graphs']
#
# Cluster 129
# KeyBERT: ['graphs', 'cycle', 'graph', 'hamiltonian', 'peterson']
#
# Cluster 130
# KeyBERT: ['gcd', 'theorem', 'integers', 'integer', 'prime']
#
# Cluster 131
# KeyBERT: ['euler', 'eulers', 'graphs', 'graph', 'vertex']
#
# Cluster 132
# KeyBERT: ['terms', 'summation', 'sum', 'equal', 'expression']
#
# Cluster 133
# KeyBERT: ['edges', 'faces', 'equal', 'summation', 'prove']
#
# Cluster 134
# KeyBERT: ['gcd', 'divides', 'divisor', 'coprime', 'divided']
#
# Cluster 135
# KeyBERT: ['divisors', 'divisor', 'divides', 'gcd', 'common']
#
# Cluster 136
# KeyBERT: ['vertex', 'edges', 'counting', 'equal', 'entered']
#
# Cluster 137
# KeyBERT: ['cycle', 'edges', 'uv', 'edge', 'assumptions']
#
# Cluster 138
# KeyBERT: ['edges', 'edge', 'diagonals', 'add', 'added']
#
# Cluster 139
# KeyBERT: ['vertex', 'vertices', 'parts', 'contains', 'split']
#
# Cluster 140
# KeyBERT: ['weighted', 'weights', 'graphs', 'weight', 'edges']
#
# Cluster 141
# KeyBERT: ['graphs', 'regularity', 'graph', 'regular', 'vertex']
#
# Cluster 142
# KeyBERT: ['vertex', 'vertices', 'graphs', 'graph', 'degrees']
#
# Cluster 143
# KeyBERT: ['vertex', 'vertices', 'diametrically', 'edges', 'symmetric']
#
# Cluster 144
# KeyBERT: ['vertices', 'vertex', 'graph', 'spokes', 'handshakes']
#
# Cluster 145
# KeyBERT: ['walk', 'walks', 'paths', 'graph', 'vertices']
#
# Cluster 146
# KeyBERT: ['edges', 'vertices', 'tree', 'induction', 'edge']
#
# Cluster 147
# KeyBERT: ['edges', 'symmetry', 'edge', 'handshakes', 'graph']
#
# Cluster 148
# KeyBERT: ['diagonals', 'spanning', 'trees', 'diagonal', 'kfor']
#
# Cluster 149
# KeyBERT: ['paths', 'path', 'connected', 'walk', 'transitive']
#
# Cluster 150
# KeyBERT: ['reflexive', 'relation', 'vertex', 'transitive', 'vertices']
#
# Cluster 151
# KeyBERT: ['vertex', 'vertices', 'edges', 'stranded', 'condition']
#
# Cluster 152
# KeyBERT: ['vertex', 'vertices', 'stranded', 'edges', 'moving']
#
# Cluster 153
# KeyBERT: ['cut', 'flow', 'star', 'theorem', 'path']
#
# Cluster 154
# KeyBERT: ['spanning', 'trees', 'tree', 'edges', 'graph']
#
# Cluster 155
# KeyBERT: ['minimal', 'spanning', 'trees', 'tree', 'weights']
#
# Cluster 156
# KeyBERT: ['greater', 'equal', 'symmetric', 'antisymmetric', 'inequalities']
#
# Cluster 157
# KeyBERT: ['vertex', 'graph', 'edges', 'edge', 'connected']
#
# Cluster 158
# KeyBERT: ['cycle', 'cycles', 'graphs', 'graph', 'traversed']
#
# Cluster 159
# KeyBERT: ['relation', 'diagram', 'hostler', 'order', 'equal']
#
# Cluster 160
# KeyBERT: ['relations', 'relation', 'reflexivity', 'transitivity', 'symmetric']
#
# Cluster 161
# KeyBERT: ['adjacency', 'graphs', 'vertices', 'vertex', 'graph']
#
# Cluster 162
# KeyBERT: ['proofer', 'diction', 'coding', 'tree', 'process']
#
# Cluster 163
# KeyBERT: ['nodes', 'proofer', 'node', 'leaf', 'code']
#
# Cluster 164
# KeyBERT: ['cycles', 'edges', 'cycle', 'graph', 'edge']
#
# Cluster 165
# KeyBERT: ['uniqueness', 'tree', 'trees', 'generates', 'unique']
#
# Cluster 166
# KeyBERT: ['cycle', 'traverse', 'vertex', 'path', 'walk']
#
# Cluster 167
# KeyBERT: ['cycle', 'cycles', 'euler', 'graphs', 'graph']
#
# Cluster 168
# KeyBERT: ['trees', 'tree', 'edges', 'disjoint', 'vertex']
#
# Cluster 169
# KeyBERT: ['trees', 'tree', 'graphs', 'root', 'graph']
#
# Cluster 170
# KeyBERT: ['vertex', 'vertices', 'graph', 'sets', 'components']
#
# Cluster 171
# KeyBERT: ['edges', 'edge', 'vertices', 'graph', 'vertex']
#
# Cluster 172
# KeyBERT: ['edges', 'edge', 'cut', 'vertices', 'graph']
